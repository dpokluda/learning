# %%
import sys

print(sys.executable)
# Out:
# c:\Users\davidpokluda\AppData\Local\Programs\Python\Python314\python.exe

# %%
import torch

print(f"torch       : {torch.__version__}")
# Out:
# torch       : 2.12.0+cpu

# %%
import matplotlib
print(f"matplotlib  : {matplotlib.__version__}")
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot([1, 2, 3], [1, 4, 9]); plt.title("Simple Plot"); plt.show()
# Out:
# matplotlib  : 3.10.9
